# %% [markdown]
# # ASSIGNMENT NO 4

# %%
#inporting libraries
from bs4 import BeautifulSoup
import requests
import selenium
from selenium import webdriver
import time
import pandas as pd
import numpy as np
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException,ElementNotInteractableException
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url= https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
#
# You need to find following details:
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
driver = webdriver.Chrome(r"C://chromedriver.exe")

# %%
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
#scraping rank of the video
rank=[]
try:
    ranks=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]")
    for i in ranks:
        rank.append(i.text)
except NoSuchElementException:#handling no such element exception
    rank.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    rank.append('No details available')
print(len(rank))
# Out:
# 30

# %%
#scraping name of the videos
name=[]
try:
    names=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]")
    for i in names:
        name.append(i.text)
except NoSuchElementException:#handling no such element exception
    name.append('No Details Available')
except StaleElementReferenceException:#handling Stale element exception
    name.append('No Details Availale')
print(len(name))
# Out:
# 30

# %%
#scraping artist/uploader of the video
artist=[]
try:
    artists=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")
    for i in artists:
        artist.append(i.text)
except NoSuchElementException:#handling no such element exception
    artist.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    artist.append('No details available')
print(len(artist))
# Out:
# 30

# %%
#scraping views in billions of the video
views=[]
try:
    view_list=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")
    for i in view_list:
        views.append(i.text)
except NoSuchElementException:#handling no such element exception
    view.append('No Details Available')
except StaleElementReferenceException:#handling Stale element exception
    views.append('No Details Available')
print(len(views))
# Out:
# 30

# %%
#scraping upload date of the video
upload_date=[]
try:
    date_list=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")
    for i in date_list:
        upload_date.append(i.text)
except NoSuchElementException:#handling no such element exception
    upload_date.append('No Details Available')
except StaleElementReferenceException:#handling Stale element exception
    upload_date.append('No Details Available')
print(len(upload_date))
# Out:
# 30

# %%
youtube=pd.DataFrame({})
youtube['Rank']=rank
youtube['Name Of Videos']=name
youtube['Artist']=artist
youtube['Views in Billions']=views
youtube['Upload Date']=upload_date
youtube
# Out:
#    Rank                                   Name Of Videos  \
# 0    1.                           "Baby Shark Dance"[22]
# 1    2.                                  "Despacito"[24]
# 2    3.                               "Shape of You"[25]
# 3    4.                       "Johny Johny Yes Papa"[26]
# 4    5.                              "See You Again"[27]
# 5    6.   "Masha and the Bear – Recipe for Disaster"[30]
# 6    7.                                "Uptown Funk"[31]
# 7    8.                              "Gangnam Style"[32]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[34]
# 9   10.                                  "Bath Song"[35]
# 10  11.                "Phonics Song with Two Words"[36]
# 11  12.                                      "Sugar"[37]
# 12  13.                                      "Sorry"[38]
# 13  14.                                       "Roar"[39]
# 14  15.                             "Dame Tu Cosita"[40]
# 15  16.                             "Counting Stars"[41]
# 16  17.                          "Thinking Out Loud"[42]
# 17  18.                                 "Dark Horse"[43]
# 18  19.                                      "Faded"[44]
# 19  20.                               "Shake It Off"[45]
# 20  21.                                    "Lean On"[46]
# 21  22.                                   "Bailando"[47]
# 22  23.                             "Girls Like You"[48]
# 23  24.                                 "Let Her Go"[49]
# 24  25.                          "Wheels on the Bus"[50]
# 25  26.                                   "Mi Gente"[51]
# 26  27.                                    "Perfect"[52]
# 27  28.                                      "Hello"[53]
# 28  29.           "Waka Waka (This Time for Africa)"[54]
# 29  30.                                     "Axel F"[55]
#
#                             Artist Views in Billions        Upload Date
# 0   Pinkfong Kids' Songs & Stories              8.50      June 17, 2016
# 1                       Luis Fonsi              7.33   January 12, 2017
# 2                       Ed Sheeran              5.30   January 30, 2017
# 3                      LooLoo Kids              5.27    October 8, 2016
# 4                      Wiz Khalifa              5.09      April 6, 2015
# 5                       Get Movies              4.43   January 31, 2012
# 6                      Mark Ronson              4.17  November 19, 2014
# 7                              Psy              4.06      July 15, 2012
# 8                      Miroshka TV              4.01  February 27, 2018
# 9       Cocomelon – Nursery Rhymes              3.99        May 2, 2018
# 10                       ChuChu TV              3.81      March 6, 2014
# 11                        Maroon 5              3.45   January 14, 2015
# 12                   Justin Bieber              3.43   October 22, 2015
# 13                      Katy Perry              3.34  September 5, 2013
# 14                       El Chombo              3.30      April 5, 2018
# 15                     OneRepublic              3.28       May 31, 2013
# 16                      Ed Sheeran              3.25    October 7, 2014
# 17                      Katy Perry              3.06  February 20, 2014
# 18                     Alan Walker              3.05   December 3, 2015
# 19                    Taylor Swift              3.05    August 18, 2014
# 20            Major Lazer Official              3.03     March 22, 2015
# 21                Enrique Iglesias              3.02     April 11, 2014
# 22                        Maroon 5              3.02       May 31, 2018
# 23                       Passenger              2.98      July 25, 2012
# 24      Cocomelon – Nursery Rhymes              2.94       May 24, 2018
# 25                        J Balvin              2.91      June 29, 2017
# 26                      Ed Sheeran              2.83   November 9, 2017
# 27                           Adele              2.83   October 22, 2015
# 28                         Shakira              2.81       June 4, 2010
# 29                      Crazy Frog              2.78      June 16, 2009

# %% [markdown]
# # 2. Scrape the details team India’s international fixtures from bcci.tv.
#
# Url = https://www.bcci.tv/.
#
# You need to find following details:
#
# A) Match title (I.e. 1st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
driver=webdriver.Chrome(r"C://chromedriver.exe")

# %%
url="https://www.bcci.tv/"

# %%
driver.get(url)

# %%
fixtures=driver.find_element_by_xpath("//div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']/div/ul/li/a")
try:
    fixtures.click()
except ElementNotInteractableException:
    driver.get(fixtures.get_attribute('href'))

# %%
urls=[]
match_page=driver.find_elements_by_xpath("//div[@class='js-list']/a")
for i in match_page:
    urls.append(i.get_attribute('href'))

# %%
Match_title=[]
Series=[]
Place=[]
Date=[]
Time=[]

# %%
#scraping Match title
match_tag=driver.find_elements_by_xpath('//p[@class="fixture__additional-info"]/strong')
match_tag[:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="87cab72f-db0d-45e7-bc2a-90013c70e103")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="8172d3e0-8be5-4dca-8fd4-5257814b6447")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="8b9a8131-6cb7-4c39-859f-953f7a7160c7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="ae94c06d-0f77-4330-89e7-972ee4c748ea")>]

# %%
try:
    for i in match_tag:
        match=i.text
        Match_title.append(match)
except NoSuchElementExpection:#handling no such element exception
    Match_title.append('No Details Available')
except StaleElementReferenceException:#handling Stale element exception
    Match_title.append('No Details Available')
print(len(Match_title))
# Out:
# 6

# %%
#scraping series
series_tag=driver.find_elements_by_xpath('//span[@class="u-unskewed-text fixture__tournament-label u-truncated"]')
series_tag[:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="3d03d710-e480-4014-b96f-a633b3005265")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="5ab7c505-3b2e-4d0a-a636-ceda05b42462")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="4b015fa5-a8ec-48af-8a7b-d1b2ecd3293d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="748e1994-884e-48ad-8a11-51cacc9d6248")>]

# %%
try:
    for i in series_tag:
        Series.append(i.text)
except NoSuchElelemtExpection:#handling no such element exception
    Series.append('No Details Avaliable')
except StaleElementReferenceExpection:#handling Stale element exception
    Series.append('No Details Available')
print(len(Series))
# Out:
# 6

# %%
#scraping place 
place_tag=driver.find_elements_by_xpath("//p[@class='fixture__additional-info']/span")
place_tag[:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="a06b3883-91ee-4679-9007-115a5548eee6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="83ad0df1-bc90-4267-a6fd-508942b8a735")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="bdc6c302-8700-476c-a9d7-b3dff595452d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="d9440ab8-8d2b-4f11-9a84-e8f00c5dbfe5")>]

# %%
try:
    for i in place_tag:
        Place.append(i.text)
except NoSuchElementExpection:#handling no such element exception
    Place.append('No Details Available')
except StaleElementReferenceExpection:#handling Stale element exception
    Place.append('No Details Available')
print(len(Place))
# Out:
# 6

# %%
#scraping date 
date_tag=driver.find_elements_by_xpath("//div[@class='fixture__full-date']/span")
date_tag[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="e1812361-fbe5-4e0a-bf5c-cea04efb9d7a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="8aa1430a-7985-4218-8f95-c1edbbe684de")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="7e3e5bc3-f253-4804-97b0-86dfd4fc5c01")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="cd06d1de-ae74-4f50-87df-73fdd0bee89f")>]

# %%
try:
    for i in date_tag:
        Date.append(i.text)
except NoSuchElementExpection:#handling no such element exception
    Date.append('No Details Available')
except StaleElementReferenceExpection:#handling Stale element exception
    Date.append('No Details Available')
print(len(Date))
# Out:
# 6

# %%
#scraping time of match
time_tag=driver.find_elements_by_xpath('//div[@class="fixture__date-details"]/span[2]')
time_tag[:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="57c6b86d-841b-4424-9d94-bf2fdfaff609")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="b62b840f-5fea-4a31-b866-10a7ba25e4f7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="235ceaa8-b5de-40e2-b775-c9b1a710aa1b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aefb1c891fc2fd8fb11b71dca16b5bbc", element="a4ffcfc2-365f-4c1a-8538-2c915e2105c7")>]

# %%
try:
    for i in time_tag:
        Time.append(i.text)
except NoSuchElementExpection:#handling no such element exception
    Time.append('No Details Available')
except StaleElementReferenceExpection:#handling Stale element exception
    Time.append('No Details Available')
print(len(Time))
# Out:
# 6

# %%
icc=pd.DataFrame({})
icc['Match Title']=Match_title
icc['Series Played']=Series
icc['Place of Match']=Place
icc['Date of Match']=Date
icc['Timeing of Match']=Time
icc
# Out:
#   Match Title                      Series Played               Place of Match  \
# 0       Final  ICC WORLD TEST CHAMPIONSHIP FINAL  The Ageas Bowl, Southampton
# 1    1st Test               ENGLAND V INDIA 2021     Trent Bridge, Nottingham
# 2    2nd Test               ENGLAND V INDIA 2021               Lord's, London
# 3    3rd Test               ENGLAND V INDIA 2021            Headingley, Leeds
# 4    4th Test               ENGLAND V INDIA 2021             The Oval, London
# 5    5th Test               ENGLAND V INDIA 2021     Old Trafford, Manchester
#
#   Date of Match Timeing of Match
# 0            18        15:30 IST
# 1            04        15:30 IST
# 2            12        15:30 IST
# 3            25        15:30 IST
# 4            02        15:30 IST
# 5            10        15:30 IST

# %% [markdown]
# # 3. Scrape the details of selenium exception from guru99.com.
#
# Url = https://www.guru99.com/
#
# You need to find following details:
#
# A) Name
#
# B) Description
#
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
driver = webdriver.Chrome(r"C://chromedriver.exe")

# %%
url='https://www.guru99.com/'

# %%
driver.get(url)

# %%
selenium_link=driver.find_element_by_xpath("//li[@class='g-menu-item g-menu-item-type-component g-menu-item-121  ']/a")
try:
    selenium_link.click()
except ElementNotInteractableException:
    driver.get(selenium_link.get_attribute('href'))

# %%
exception_handle_link=driver.find_element_by_xpath("//a[@title='Selenium Exception Handling (Common Exceptions List)']")
try:
    exception_handle_link.click()
except ElementNotInteractableException:
    driver.get(exception_handle_link.get_attribute('href'))

# %%
name=[]
try:
    names=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[1]")
    for i in names[1:]:
        name.append(i.text)
except NoSuchElementException:#handling no such element exception
    name.append('No details available')
print(len(name))
# Out:
# 41

# %%
desc=[]
try:
    desc_list=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[2]")
    for i in desc_list[1:]:
        desc.append(i.text)
except NoSuchElementException:#handling no such element exception
    desc.append('No details available')
print(len(desc))
# Out:
# 41

# %%
guru=pd.DataFrame({})
guru['Exception Name']=name
guru['Description']=desc
guru
# Out:
#                          Exception Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# 22            InvalidSessionIdException
# 23       InvalidSwitchToTargetException
# 24                  JavascriptException
# 25                        JsonException
# 26             NoSuchAttributeException
# 27       MoveTargetOutOfBoundsException
# 28               NoSuchContextException
# 29                NoSuchCookieException
# 30                    NotFoundException
# 31          RemoteDriverServerException
# 32                  ScreenshotException
# 33           SessionNotCreatedException
# 34           UnableToSetCookieException
# 35           UnexpectedTagNameException
# 36              UnhandledAlertException
# 37      UnexpectedAlertPresentException
# 38               UnknownMethodException
# 39          UnreachableBrowserException
# 40          UnsupportedCommandException
#
#                                           Description
# 0   This type of Selenium exception occurs when an...
# 1   This Selenium exception occurs when an element...
# 2   This Exception occurs if an element could not ...
# 3   This Exception occurs if the frame target to b...
# 4   This Exception occurs when you switch to no pr...
# 5   This Exception occurs if the window target to ...
# 6   This Selenium exception occurs happens when th...
# 7   The WebDriver is acting after you quit the bro...
# 8   Thrown when there is not enough time for a com...
# 9   This Exception takes place when the WebDriver ...
# 10  This type of Exception takes place when there ...
# 11  The command may not be completed as the elemen...
# 12  This Selenium exception is thrown when any ele...
# 13  This happens while interacting with the Firefo...
# 14  Exception is used as a placeholder in case if ...
# 15  This expectation will occur when IME engine ac...
# 16    It takes place when IME support is unavailable.
# 17  Navigation made the user agent to hit a certif...
# 18  It occurs when an argument does not belong to ...
# 19  This happens when you try to add a cookie unde...
# 20  This type of Exception matches an interacting ...
# 21  It occurs when command can't be finished when ...
# 22  This Exception took place when the given sessi...
# 23  This occurs when the frame or window target to...
# 24  This issue occurs while executing JavaScript g...
# 25  It occurs when you afford to get the session w...
# 26  This kind of Exception occurs when the attribu...
# 27  It takes place if the target provided to the A...
# 28           ContextAware does mobile device testing.
# 29  This Exception occurs when no cookie matching ...
# 30  This Exception is a subclass of WebDriverExcep...
# 31  This Selenium exception is thrown when the ser...
# 32            It is not possible to capture a screen.
# 33  It happens when a new session could not be suc...
# 34  This occurs if a driver is unable to set a coo...
# 35  Happens if a support class did not get a web e...
# 36  This expectation occurs when there is an alert...
# 37  It occurs when there is the appearance of an u...
# 38  This Exception happens when the requested comm...
# 39  This Exception occurs only when the browser is...
# 40  This occurs when remote WebDriver does n't sen...

# %% [markdown]
# # 4. Scrape the details of State-wise GDP of India from statisticstime.com.
#
# Url = http://statisticstimes.com/
#
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP(18-19)
#
# D) GSDP(17-18)
#
# E) Share(2017)
#
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
driver = webdriver.Chrome(r"C://chromedriver.exe")

# %%
driver.get("http://statisticstimes.com/")

# %%
economy=driver.find_element_by_xpath("//div[@class='dropdown'][2]/div/a[3]")

# %%
try:
    economy.click()
except ElementNotInteractableException:
    driver.get(economy.get_attribute('href'))

# %%
GDP=driver.find_element_by_xpath("//ul[@style='list-style-type:none;margin-left:20px;']/li/a")
try:
    GDP.click()
except ElementNotInteractableException:
    driver.get(GDP.get_attribute('href'))

# %%
rank=[]
try:
    ranks=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[1]")
    for i in ranks:
        rank.append(i.text)
except NoSuchElementException:#handling no such element exception
    rank.append('No details available')
print(len(rank))
# Out:
# 33

# %%
State=[]
try:
    states=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[2]")
    for i in states:
        State.append(i.text)
except NoSuchElementException:#handling no such element exception
    State.append('No details available')
print(len(State))
# Out:
# 33

# %%
GSDP_19=[]
try:
    info=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[3]")
    for i in info:
        GSDP_19.append(i.text)
except NoSuchElementException:#handling no such element exception
    GSDP_19.append('No details available')
print(len(GSDP_19))
# Out:
# 33

# %%
GSDP_18=[]
try:
    info=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[4]")
    for i in info:
        GSDP_18.append(i.text)
except NoSuchElementException:#handling no such element exception
    GSDP_18.append('No details available')
print(len(GSDP_18))
# Out:
# 33

# %%
share=[]
try:
    info=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[5]")
    for i in info:
        share.append(i.text)
except NoSuchElementException:#handling no such element exception
    share.append('No details available')
print(len(share))
# Out:
# 33

# %%
GDP_billion=[]
try:
    info=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[6]")
    for i in info:
        GDP_billion.append(i.text)
except NoSuchElementException:#handling no such element exception
    GDP_billion.append('No details available')
print(len(GDP_billion))
# Out:
# 33

# %%
State_wise_GDP_of_India=pd.DataFrame({})
State_wise_GDP_of_India['Rank']=rank
State_wise_GDP_of_India['State']=State
State_wise_GDP_of_India['GSDP_19_20']=GSDP_19
State_wise_GDP_of_India['GSDP_18_19']=GSDP_18
State_wise_GDP_of_India['Share_2018']=share
State_wise_GDP_of_India['GDP_billion_dollar']=GDP_billion

# %%
State_wise_GDP_of_India
# Out:
#    Rank                      State GSDP_19_20 GSDP_18_19 Share_2018  \
# 0     1                Maharashtra          -  2,632,792     13.88%
# 1     2                 Tamil Nadu  1,845,853  1,630,208      8.59%
# 2     3              Uttar Pradesh  1,687,818  1,584,764      8.35%
# 3     4                    Gujarat          -  1,502,899      7.92%
# 4     5                  Karnataka  1,631,977  1,493,127      7.87%
# 5     6                West Bengal  1,253,832  1,089,898      5.75%
# 6     7                  Rajasthan  1,020,989    942,586      4.97%
# 7     8             Andhra Pradesh    972,782    862,957      4.55%
# 8     9                  Telangana    969,604    861,031      4.54%
# 9    10             Madhya Pradesh    906,672    809,592      4.27%
# 10   11                     Kerala          -    781,653      4.12%
# 11   12                      Delhi    856,112    774,870      4.08%
# 12   13                    Haryana    831,610    734,163      3.87%
# 13   14                      Bihar    611,804    530,363      2.80%
# 14   15                     Punjab    574,760    526,376      2.77%
# 15   16                     Odisha    521,275    487,805      2.57%
# 16   17                      Assam          -    315,881      1.67%
# 17   18               Chhattisgarh    329,180    304,063      1.60%
# 18   19                  Jharkhand    328,598    297,204      1.57%
# 19   20                Uttarakhand          -    245,895      1.30%
# 20   21            Jammu & Kashmir          -    155,956      0.82%
# 21   22           Himachal Pradesh    165,472    153,845      0.81%
# 22   23                        Goa     80,449     73,170      0.39%
# 23   24                    Tripura     55,984     49,845      0.26%
# 24   25                 Chandigarh          -     42,114      0.22%
# 25   26                 Puducherry     38,253     34,433      0.18%
# 26   27                  Meghalaya     36,572     33,481      0.18%
# 27   28                     Sikkim     32,496     28,723      0.15%
# 28   29                    Manipur     31,790     27,870      0.15%
# 29   30                   Nagaland          -     27,283      0.14%
# 30   31          Arunachal Pradesh          -     24,603      0.13%
# 31   32                    Mizoram     26,503     22,287      0.12%
# 32   33  Andaman & Nicobar Islands          -          -          -
#
#    GDP_billion_dollar
# 0             398.145
# 1             246.529
# 2             239.656
# 3             227.276
# 4             225.798
# 5             164.820
# 6             142.543
# 7             130.501
# 8             130.210
# 9             122.431
# 10            118.206
# 11            117.180
# 12            111.024
# 13             80.204
# 14             79.601
# 15             73.768
# 16             47.769
# 17             45.982
# 18             44.945
# 19             37.186
# 20             23.584
# 21             23.265
# 22             11.065
# 23              7.538
# 24              6.369
# 25              5.207
# 26              5.063
# 27              4.344
# 28              4.215
# 29              4.126
# 30              3.721
# 31              3.370
# 32                  -

# %% [markdown]
# # 5. Scrape the details of trending repositories on Github.com.
#
# Url = https://github.com/
#
# You have to find the following details:
#
# A) Repository title
#
# B) Repository description
#
# C) Contributors count
#
# D) Language used
#
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
driver = webdriver.Chrome(r"C://chromedriver.exe")

# %%
driver.get("https://github.com/")

# %%
explore=driver.find_element_by_xpath("//ul[@class='list-style-none mb-3']/li[3]/a")
driver.get(explore.get_attribute('href'))

# %%
repo_title=[]
try:
    repos=driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']")
    for i in repos:
        repo_title.append(i.text)
except NoSuchElementException:#handling no such element exception
    repo_title.append('No details available')
print(len(repo_title))
# Out:
# 25

# %%
repo_desc=[]
try:
    desc=driver.find_elements_by_xpath("//p[@class='col-9 color-text-secondary my-1 pr-4']")
    for i in desc:
        repo_desc.append(i.text)
except NoSuchElementException:#handling no such element exception
    repo_desc.append('No details available')
print(len(repo_desc))
# Out:
# 23

# %%
repo_urls=[]
repos=driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']/a")
for i in repos:
    repo_urls.append(i.get_attribute('href'))

# %%
Contributors_count=[]
Language_used=[]
for i in repo_urls:
    driver.get(i)
    l=[]
    try:
        count=driver.find_element_by_xpath("//h2[@class='h4 mb-3']/a[contains(text(),'Contributors')]/span")
        Contributors_count.append(count.text)
    except NoSuchElementException:#handling no such element exception
        Contributors_count.append('No details available')
        
    languages=driver.find_elements_by_xpath("//span[@class='text-gray-dark text-bold mr-1']")
    if languages:    
        for i in languages:
            l.append(i.text)
    else:
        l.append('No languages used')
    Language_used.append(l)

# %%
trending_repositories=pd.DataFrame({})
trending_repositories['Repository_title']=repo_title[0:22]
trending_repositories['Repository_description']=repo_desc[0:22]
trending_repositories['Contributors_count']=Contributors_count[0:22]
trending_repositories['Language_used']=Language_used[0:22]

# %%
trending_repositories
# Out:
#                                      Repository_title  \
# 0                     pallupz / covid-vaccine-booking
# 1                                   slidevjs / slidev
# 2                           Uniswap / uniswap-v3-core
# 3                                  pixie-labs / pixie
# 4                                   flutter / flutter
# 5                                       axios / axios
# 6                               andymatuschak / orbit
# 7                                 dogecoin / dogecoin
# 8   abuanwar072 / Flutter-Responsive-Admin-Panel-o...
# 9                     jlevy / the-art-of-command-line
# 10                          public-apis / public-apis
# 11              jwasham / coding-interview-university
# 12                                      kcp-dev / kcp
# 13                      LeCoupa / awesome-cheatsheets
# 14           trimstray / the-book-of-secret-knowledge
# 15                          seemoo-lab / openhaystack
# 16                             vinta / awesome-python
# 17                                 Azure / counterfit
# 18                       imarvinle / awesome-cs-books
# 19                                audacity / audacity
# 20                     Uniswap / uniswap-v3-periphery
# 21                                   itdevbooks / pdf
#
#                                Repository_description    Contributors_count  \
# 0   This very basic script can be used to automate...                     8
# 1   Presentation Slides for Developers (Public Bet...                    11
# 2            🦄 🦄 🦄 Core smart contracts of Uniswap v3                     8
# 3   Instant Kubernetes-Native Application Observab...                    14
# 4   Flutter makes it easy and fast to build beauti...                   851
# 5   Promise based HTTP client for the browser and ...                   270
# 6                                       very currency                     3
# 7   Responsive Admin Panel or Dashboard using Flutter                   201
# 8                Master the command line, in one page  No details available
# 9                      A collective list of free APIs                   162
# 10  A complete computer science study plan to beco...                   766
# 11  kcp is a prototype of a Kubernetes API server ...                   196
# 12  👩‍💻👨‍💻 Awesome cheatsheets for popular program...                     8
# 13  A collection of inspiring lists, manuals, chea...                    95
# 14  Build your own 'AirTags' 🏷 today! Framework fo...                    80
# 15  A curated list of awesome Python frameworks, l...                     6
# 16  a CLI that provides a generic automation layer...                   391
# 17  经典编程书籍大全，涵盖：计算机系统与网络、系统架构、算法与数据结构、前端开发、后端开发、移动...  No details available
# 18                                       Audio Editor  No details available
# 19  🦄 🦄 🦄 Peripheral smart contracts for interacti...                   126
# 20  编程电子书，电子书，编程书籍，包括C，C#，Docker，Elasticsearch，Git...                     8
# 21                           tokio-console prototypes  No details available
#
#           Language_used
# 0   [No languages used]
# 1   [No languages used]
# 2   [No languages used]
# 3   [No languages used]
# 4   [No languages used]
# 5   [No languages used]
# 6   [No languages used]
# 7   [No languages used]
# 8   [No languages used]
# 9   [No languages used]
# 10  [No languages used]
# 11  [No languages used]
# 12  [No languages used]
# 13  [No languages used]
# 14  [No languages used]
# 15  [No languages used]
# 16  [No languages used]
# 17  [No languages used]
# 18  [No languages used]
# 19  [No languages used]
# 20  [No languages used]
# 21  [No languages used]

# %% [markdown]
# # 6. Scrape the details of top 100 songs on billiboard.com.
#
# Url = https://www.billboard.com/
#
# You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board
#
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver = webdriver.Chrome(r"C://chromedriver.exe")

# %%
driver.get("https://www.billboard.com/")

# %%
charts=driver.find_element_by_xpath("//a[@class='header__main-link header__main-link--charts']")
try:
    charts.click()
except ElementNotInteractableException:
    driver.get(charts.get_attribute('href'))

# %%
top_100=driver.find_element_by_xpath("//a[@class='charts-landing__link charts-landing__video--background']")
try:
    top_100.click()
except ElementNotInteractableException:
    driver.get(top_100.get_attribute('href'))

# %%
song_name=[]
try:
    names=driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']")
    for i in names:
        song_name.append(i.text)
except NoSuchElementException:#handling no such element exception
    song_name.append('No details avaliable')
print(len(song_name))
# Out:
# 100

# %%
artist_name=[]
try:
    artist=driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']")
    for i in artist:
        artist_name.append(i.text)
except NoSuchElementException:#handling no such element exception
    artist_name.append('No detail avaliable')
print(len(artist_name))
# Out:
# 100

# %%
last_week_rank=[]
try:
    ranks=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
    for i in ranks:
        last_week_rank.append(i.text)
except NoSuchElementException:#handling no such element exception
    last_week_rank.append('No details available')
print(len(last_week_rank))
# Out:
# 100

# %%
peak_rank=[]
try:
    ranks=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
    for i in ranks:
        peak_rank.append(i.text)
except NoSuchElementException:#handling no such element exception
    peak_rank.append('No detail avaliable')
print(len(peak_rank))
# Out:
# 100

# %%
weeks=[]
try:
    week=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")
    for i in week:
        weeks.append(i.text)
except NoSuchElementException:#handling no such element exception
    weeks.append('No detail avaliable')
print(len(weeks))
# Out:
# 100

# %%
Billboard=pd.DataFrame({})
Billboard['Song Name']=song_name
Billboard['Artist Name']=artist_name
Billboard['Last Week Rank']=last_week_rank
Billboard['Peak Rank']=peak_rank
Billboard['Week On Board']=weeks

# %%
Billboard
# Out:
#               Song Name                                     Artist Name  \
# 0       Save Your Tears                      The Weeknd & Ariana Grande
# 1   Leave The Door Open        Silk Sonic (Bruno Mars & Anderson .Paak)
# 2               Peaches  Justin Bieber Featuring Daniel Caesar & Giveon
# 3               Rapstar                                          Polo G
# 4            Levitating                       Dua Lipa Featuring DaBaby
# ..                  ...                                             ...
# 95            4 Da Gang                           42 Dugg & Roddy Ricch
# 96      Blame It On You                                    Jason Aldean
# 97        Wasted On You                                   Morgan Wallen
# 98         Way Less Sad                                             AJR
# 99         Clear Da Air                                    Moneybagg Yo
#
#    Last Week Rank Peak Rank Week On Board
# 0               6         1            20
# 1               2         1             8
# 2               3         1             6
# 3               1         1             3
# 4               5         5            30
# ..            ...       ...           ...
# 95            100        67             4
# 96              -        97             1
# 97             92         9            16
# 98              -        99             1
# 99              -       100             1
#
# [100 rows x 5 columns]

# %% [markdown]
# # 7. Scrape the details of Data science recruiters from naukri.com.
#
# Url = https://www.naukri.com/
#
# You have to find the following details:
#
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location
#
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code

# %%
driver = webdriver.Chrome(r"C://chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
#clicking on recruiters link
recruiters=driver.find_element_by_xpath("//a[@title='Search Recruiters']")
driver.get(recruiters.get_attribute('href'))

# %%
#accesing search bar
search=driver.find_element_by_xpath("//input[@class='sugInp']")
search.send_keys("Data Science")

# %%
#search button
button=driver.find_element_by_xpath("//button[@id='qsbFormBtn']")
button.click()

# %%
#scrapping names
name=[]
try:
    names=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/a[1]")
    for i in names:
        name.append(i.text)
except NoSuchElementException:#handling no such element exception
    name.append('No details available')
print(len(name))
# Out:
# 50

# %%
#scrapping destination
designation=[]
try:
    designation_list=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/span[1]")
    for i in designation_list:
        designation.append(i.text)
except NoSuchElementException:#handling no such element exception
    designation.append('No details available')
print(len(designation))
# Out:
# 50

# %%
#scraping company name
company=[]
try:
    company_list=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/a[2]")
    for i in company_list:
        company.append(i.text)
except NoSuchElementException:#handling no such element exception
    company.append('No detail avaliable')
print(len(company))
# Out:
# 50

# %%
#skills they hire for
skill=[]
try:
    skills=driver.find_elements_by_xpath("//div[@class='recInfo']/div[2]")
    for i in skills:
        skill.append(i.text)
except NoSuchElementException:#handling no such element exception
    skill.append('No details available')
print(len(skill))
# Out:
# 50

# %%
#scraping location
location=[]
soup=BeautifulSoup(driver.page_source,'html.parser')
l=soup.find_all('div',attrs={'vcard'})
for i in l:
    try:
        location.append(i.find('small').text)
    except AttributeError :
        location.append("No details available")
print(len(location))
# Out:
# 50

# %%
Data_science_recruiters=pd.DataFrame({})
Data_science_recruiters["Name"]=name
Data_science_recruiters["Designation"]=designation
Data_science_recruiters["Company Name"]=company
Data_science_recruiters["Location"]=location
Data_science_recruiters["Skills I Hire"]=skill

# %%
Data_science_recruiters
# Out:
#    Name                          Designation  \
# 0                                 HR Manager
# 1                          Company Recruiter
# 2                   Recruitment Professional
# 3                          Company Recruiter
# 4                                 Company HR
# 5                                Founder CEO
# 6                Recruitment Lead Consultant
# 7                          Programme Manager
# 8                           HR Administrator
# 9                                   Director
# 10                            Human Resource
# 11                          Executive Hiring
# 12                                Company HR
# 13                                Company HR
# 14       Senior Executive Talent Acquisition
# 15                              HR Team Lead
# 16                                HR Manager
# 17                            Senior Manager
# 18                              HR Executive
# 19                Manager Talent Acquisition
# 20                                   HR Head
# 21                                HR MANAGER
# 22                              HR Recruiter
# 23                         Company Recruiter
# 24                              HR Recruiter
# 25                   Manager Human Resources
# 26                   Lead Talent acquisition
# 27                                Proprietor
# 28                                       CEO
# 29                               Founder CEO
# 30                  Company Recruitment Head
# 31                           Project Manager
# 32                    Recruitment Consultant
# 33                                      Head
# 34                                Consultant
# 35              senior technology instructor
# 36                  HR Recruiter/HR Excutive
# 37             Manager, Technical Recruiting
# 38                       Technical Recruiter
# 39                           Erp Implementer
# 40                            Head Analytics
# 41                   Chief Technical Officer
# 42                        Sr Product Manager
# 43                  Director Global Delivery
# 44                                Co Founder
# 45                                HR Manager
# 46                                 Architect
# 47                          Managing Partner
# 48                                HR Manager
# 49                    Managing Director - HR
#
#                                       Company Name                  Location  \
# 0                             Data Science Network                     Delhi
# 1                    Shore Infotech India Pvt. Ltd  Hyderabad / Secunderabad
# 2                                       XenonStack                Chandigarh
# 3            Enerlytics Software Solutions Pvt Ltd                 Ahmedabad
# 4                         MARSIAN Technologies LLP                      Pune
# 5                                  LibraryXProject             UK - (london)
# 6       Apidel Technologies Division of Transpower         Vadodara / Baroda
# 7                                             IFMR                   Chennai
# 8                      Techvantage Systems Pvt Ltd                Trivandrum
# 9                       Weupskill- Live Wire India                    Indore
# 10                CBL Data Science Private Limited     Bengaluru / Bangalore
# 11                              Innominds Software  Hyderabad / Secunderabad
# 12                                        MoneyTap     Bengaluru / Bangalore
# 13              QuantMagnum Technologies Pvt. Ltd.                    Mumbai
# 14                           Bristlecone India Ltd                    Nagpur
# 15                               SocialPrachar.com  Hyderabad / Secunderabad
# 16                                  BISP Solutions                    Bhopal
# 17                          Independent Consultant     Bengaluru / Bangalore
# 18                                        Easi Tax               Navi Mumbai
# 19                     Novelworx Digital Solutions                    Cochin
# 20         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...                     Delhi
# 21                   FirstTech Consaltants Pvt.Ltd  Hyderabad / Secunderabad
# 22                                Affine Analytics                      Pune
# 23                 NEAL ANALYTICS SERVICES PVT LTD                      Pune
# 24                 Compumatrice Multimedia Pvt Ltd                      Pune
# 25                              Exela Technologies                      Pune
# 26      Autumn Leaf Consulting Services Private...     Bengaluru / Bangalore
# 27                                         trainin     Bengaluru / Bangalore
# 28                            Nanoprecise Sci Corp      No details available
# 29                  R.S Consultancy &amp; Services                     Delhi
# 30                                    Confidential     Bengaluru / Bangalore
# 31        Dollarbird Information Services Pvt, Ltd           Mysoru / Mysore
# 32     JOBSMILL BUSINESS SOLUTIONS PRIVATE LIMITED  Hyderabad / Secunderabad
# 33                                         Trisect                     Noida
# 34                                 ASCO consulting                 New Delhi
# 35                                         NY INST                   Chennai
# 36  3D India Staffing Research &amp; Consulting...                   Aligarh
# 37                                     O.C. Tanner            Salt Lake City
# 38                                   Demand Matrix                      Pune
# 39                             MADHUSUDHAN SRIDHAR     Bengaluru / Bangalore
# 40                                  Suntech Global                    Mumbai
# 41                        Strategic Consulting Lab                    Indore
# 42                            Impel Labs Pvt. Ltd.     Bengaluru / Bangalore
# 43                                    MRP Advisers                    MYSORE
# 44                   Saras Solutions India Pvt Ltd  Hyderabad / Secunderabad
# 45                                     WildJasmine     Bengaluru / Bangalore
# 46                             LNT Private Limited                    Mumbai
# 47                                     Granular.ai      No details available
# 48                               Certybox Pvt.Ltd.                     Noida
# 49                       Western Service Providers                    Mumbai
#
#                                         Skills I Hire
# 0   Classic ASP Developer, Internet Marketing Prof...
# 1   .Net, Java, Data Science, Linux Administration...
# 2   Web Designing, html5, Angular.js, seo, hadoop,...
# 3   Mean Stack, javascript, angularjs, mongodb, We...
# 4   Data Science, Artificial Intelligence, Machine...
# 5   Hadoop, Spark, Digital Strategy, Data Architec...
# 6   Analytics, Business Intelligence, Business Ana...
# 7                                        Data Science
# 8   Machine Learning, algorithms, Go Getter, Compu...
# 9   Technical Training, Software Development, Pres...
# 10  Software Development, It Sales, Account Manage...
# 11  Qa, Ui/ux, Java Developer, Java Architect, C++...
# 12  Business Intelligence, Data Warehousing, Data ...
# 13  Office Administration, Hr Administration, tele...
# 14  Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 15  Social Media, digital media maketing, seo, smm...
# 16     Big Data, Hadoop, Data Analytics, Data Science
# 17  Data Science, Artificial Intelligence, analyti...
# 18  Telecalling, Client Interaction, Marketing, Re...
# 19                                       Data Science
# 20  Corporate Sales, Software Development, Softwar...
# 21  Data Analytics, Data Science, Machine Learning...
# 22  Data Science, Machine Learning, Python, R, Dee...
# 23  Data Science, Artificial Intelligence, Machine...
# 24  Big Data, Data Science, Artificial Intelligenc...
# 25  Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 26  Software Architecture, Vp Engineering, Product...
# 27  Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 28  Signal Processing, Machine Learning, Neural Ne...
# 29  Web Technologies, Project Management, Software...
# 30  Server Administartion, Verilog, Vhdl, Digital ...
# 31  Data Analytics, Managed Services, Team Leading...
# 32  Data Science, Machine Learning, Big Data Analy...
# 33  Java, Python, Angularjs, Software Testing, Mac...
# 34  Machine Learning, Artificial Intelligence, Dat...
# 35  C, C++, Artificial Intelligence, Python, Php, ...
# 36  Relationship Management, Retail Sales, Private...
# 37                 Data Science, Software Engineering
# 38  Data Science, Big Data Analytics, Digital Mark...
# 39                  Data Science, Recruitment, Salary
# 40  B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 41  Software Development, Business Intelligence, B...
# 42                   Data Science, Node.js, Angularjs
# 43  Data Science, Media Marketing, Resource Planni...
# 44  Data Analysis, Learning, Data Science, Compute...
# 45  Java, Hadoop, R, Machine Learning, Spark, Flum...
# 46  Software Development, Core Java, Unit Testing,...
# 47  Machine Learning, Data Science, Product Manage...
# 48  consulting, Education Counseling, Educational ...
# 49  Software Professionals, Engineering, Technical...

# %% [markdown]
# # 8. Scrape the details of Highest selling novels.
#
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/
#
# You have to find the following details:
#
# A) Book name
#
# B) Author name
#
# C) Volumes sold
#
# D) Publisher
#
# E) Genre

# %%
driver = webdriver.Chrome(r"C://chromedriver.exe")

# %%
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
#scraping book name
book_name=[]
try:
    names=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[2]")
    for i in names:
        book_name.append(i.text)
except NoSuchElementException:#handling no such element exception
    book_name.append('No details available')
print(len(book_name))
# Out:
# 100

# %%
#scraping author name
author_name=[]
try:
    names=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[3]")
    for i in names:
        author_name.append(i.text)
except NoSuchElementException:#handling no such element exception
    author_name.append('No details available')

print(len(author_name))
# Out:
# 100

# %%
#scraping publisher name
publisher=[]
try:
    publishers=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[5]")
    for i in publishers:
        publisher.append(i.text)
except NoSuchElementException:#handling no such element exception
    publisher.append('No details available')

print(len(publisher))
# Out:
# 100

# %%
#scraping genre
genre=[]
try:
    genres=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[6]")
    for i in genres:
        genre.append(i.text)
except NoSuchElementException:#handling no such element exception
    genre.append('No details available')

print(len(genre))
# Out:
# 100

# %%
#scrapping volume sold
volume_sold=[]
try:
    volume=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[4]")
    for i in volume:
        volume_sold.append(i.text)
except NoSuchElementException:#handling no such element exception
    volume_sold.append('No details available')

print(len(volume_sold))
# Out:
# 100

# %%
Books=pd.DataFrame({})
Books['Book Name']=book_name
Books['Author Name']=author_name
Books['Volume sold out']=volume_sold
Books['Publisher']=publisher
Books['Genre']=genre

# %%
Books
# Out:
#                                             Book Name       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold out        Publisher                        Genre
# 0        5,094,805       Transworld  Crime, Thriller & Adventure
# 1        4,475,152       Bloomsbury           Children's Fiction
# 2        4,200,654       Bloomsbury           Children's Fiction
# 3        4,179,479       Bloomsbury           Children's Fiction
# 4        3,758,936     Random House              Romance & Sagas
# ..             ...              ...                          ...
# 95         807,311     Random House   General & Literary Fiction
# 96         794,201          Penguin        Food & Drink: General
# 97         792,187  Scholastic Ltd.          Young Adult Fiction
# 98         791,507            Orion           Biography: General
# 99         791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# # 9. Scrape the details most watched tv series of all time from imdb.com.
#
# Url = https://www.imdb.com/list/ls095964455/
#
# You have to find the following details:
#
# A) Name
#
# B) Year span
#
# C) Genre
#
# D) Run time
#
# E) Ratings
#
# F) Votes

# %%
driver = webdriver.Chrome(r"C://chromedriver.exe")

# %%
driver.get("https://www.imdb.com/list/ls095964455/")

# %%
#scraping name 
name=[]
try:
    names=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")
    for i in names:
        name.append(i.text)
except NosuchElementException:#handling no such element exception
    name.append('No details available')
print(len(name))
# Out:
# 100

# %%
#scraping years
years=[]
try:
    span=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/span[2]")
    for i in span:
        years.append(i.text)
except NosuchElementException:#handling no such element exception
    years.append('No details available')
print(len(years))
# Out:
# 100

# %%
#scraping genre
genre=[]
try:
    genres=driver.find_elements_by_xpath("//span[@class='genre']")
    for i in genres:
        genre.append(i.text)
except NoSuchElementException: #handling no such element exception
    genre.append('No Detail Avaliable')
print(len(genre))
# Out:
# 100

# %%
#scraping runtime
run_time=[]
try:
    time=driver.find_elements_by_xpath("//span[@class='runtime']")
    for i in time:
        run_time.append(i.text)
except NoSuchElementException: #handling No such element exception
    run_time.append('No Detail Avaliable')
print(len(run_time))
# Out:
# 100

# %%
#scraping rating
rating=[]
try:
    rate=driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']/span[2]")
    for i in rate:
        rating.append(i.text)
except NoSuchELementException: #handling no such element exception 
    rating.append('No Detail Avaliable')
print(len(rating))
# Out:
# 100

# %%
votes=[]
try:
    info=driver.find_elements_by_xpath("//span[@name='nv']")
    for i in info:
        votes.append(i.text)
except NoSuchElementException:#handling no such element exception
    votes.append('No details available')
print(len(votes))
# Out:
# 100

# %%
IMDB=pd.DataFrame({})
IMDB['Name']=name
IMDB['Year Span']=years
IMDB['Genre']=genre
IMDB['Run Time']=run_time
IMDB['Rating']=rating
IMDB['Votes']=votes

# %%
IMDB
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Rating      Votes
# 0    57 min    9.3  1,804,115
# 1    51 min    8.7    848,937
# 2    44 min    8.2    868,446
# 3    60 min    7.6    260,420
# 4    43 min    7.6    221,441
# ..      ...    ...        ...
# 95   42 min    7.5     44,253
# 96   50 min    7.8     54,706
# 97   42 min    8.1    165,673
# 98   45 min    7.2     34,610
# 99  572 min    8.6    188,447
#
# [100 rows x 6 columns]

# %% [markdown]
# # 10. Details of Datasets from UCI machine learning repositories.
#
# Url = https://archive.ics.uci.edu/
#
# You have to find the following details:
#
# A) Dataset name
#
# B) Data type
#
# C) Task
#
# D) Attribute type
#
# E) No of instances
#
# F) No of attribute
#
# G) Year
#
# Note: - from the home page you have to go to the Show All Dataset page through code.

# %%
driver = webdriver.Chrome(r"C://chromedriver.exe")

# %%
driver.get("https://archive.ics.uci.edu/ml/index.php")

# %%
#clicking show all datasets link
show=driver.find_element_by_xpath("//a[@href='datasets.php']")
show.click()

# %%
#scraping dataset names
name=[]
try:
    names=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a")
    for i in names:
        name.append(i.text)
except NoSuchElementException:#handling no such element exception
    name.append('No details available')
print(len(name))
# Out:
# 588

# %%
#scraping dataset type
data_type=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]")
    for i in info[1:]:
         data_type.append(i.text)
except NoSuchElementException:
    data_type.append("No information")
print(len(data_type))
# Out:
# 588

# %%
#scraping dataset default task
default_task=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]")
    for i in info[1:]:
         default_task.append(i.text)
except NoSuchElementException:
    default_task.append("No information")
print(len(default_task))
# Out:
# 588

# %%
#scraping dataset attribute type
attr_type=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]")
    for i in info[1:]:
         attr_type.append(i.text)
except NoSuchElementException:
    attr_type.append("No information")
print(len(attr_type))
# Out:
# 588

# %%
#scraping dataset instances
no_of_instances=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]")
    for i in info[1:]:
         no_of_instances.append(i.text)
except NoSuchElementException:
    no_of_instances.append("No information")
print(len(no_of_instances))
# Out:
# 588

# %%
#scraping dataset attribute
no_of_attributes=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]")
    for i in info[1:]:
         no_of_attributes.append(i.text)
except NoSuchElementException:
    no_of_attributes.append("No information")
print(len(no_of_attributes))
# Out:
# 588

# %%
#scraping dataset years
year=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]")
    for i in info[1:]:
         year.append(i.text)
except NoSuchElementException:
    year.append("No information")
print(len(year))
# Out:
# 588

# %%
UCI_Dataset=pd.DataFrame({})
UCI_Dataset['Name']=name
UCI_Dataset['Data Type']=data_type
UCI_Dataset['Default Task']=default_task
UCI_Dataset['Attribute Type']=attr_type
UCI_Dataset['Instance']=no_of_instances
UCI_Dataset['Attribute']=no_of_attributes
UCI_Dataset['Year']=year

# %%
UCI_Dataset
# Out:
#                                  Name      Data Type          Default Task  \
# 0                             Abalone  Multivariate        Classification
# 1                               Adult  Multivariate        Classification
# 2                           Annealing  Multivariate        Classification
# 3        Anonymous Microsoft Web Data                 Recommender-Systems
# 4                          Arrhythmia  Multivariate        Classification
# ..                                ...            ...                   ...
# 583  in-vehicle coupon recommendation  Multivariate        Classification
# 584               Gait Classification  Multivariate        Classification
# 585         Wikipedia Math Essentials   Time-Series            Regression
# 586         Wikipedia Math Essentials   Time-Series            Regression
# 587      Synchronous Machine Data Set  Multivariate            Regression
#
#                   Attribute Type Instance Attribute   Year
# 0    Categorical, Integer, Real     4177         8   1995
# 1          Categorical, Integer    48842        14   1996
# 2    Categorical, Integer, Real      798        38
# 3                   Categorical    37711       294   1998
# 4    Categorical, Integer, Real      452       279   1998
# ..                           ...      ...       ...    ...
# 583                                12684        23   2020
# 584                        Real       48       321   2020
# 585                        Real      731      1068   2021
# 586                        Real      731      1068   2021
# 587                        Real      557         5   2021
#
# [588 rows x 7 columns]
